# %% [markdown]
# # Import data
# In this Jupyter Notebook, you will learn how to import data from CSV into Jupyter Notebook

# %%
#import the package "Pandas" into Jupyter Notebook
import pandas as pd

# %%
#We import the stock data of Facebook into Jupyter Notebook. The CSV file is located in the folder called "Data" in your Workspace
#We then name the DataFrame name as 'fb'
fb = pd.DataFrame.from_csv('../data/facebook.csv')

# %% [markdown]
# ### Instruction
# Now is your turn to import the stock price of Microsoft (microsoft.csv), of which the CSV is located in the same folder, and rename the Dataframe in "ms".

# %%
ms = pd.DataFrame.from_csv('../data/microsoft.csv')

# %%
# run this cell to ensure Microsoft's stock data is imported
print(ms.iloc[0, 0])
# Out:
# 46.73

# %% [markdown]
# ** Expected output: ** 46.73

# %%
ms.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  780.000000  780.000000  780.000000  780.000000  780.000000
# mean    58.912308   59.372308   58.465000   58.945397   56.931553
# std     12.852040   12.868060   12.802831   12.830350   13.670080
# min     40.340000   40.740002   39.720001   40.290001   37.267815
# 25%     47.894998   48.295000   47.535001   47.974998   44.792073
# 50%     56.150002   56.640001   55.700001   56.209999   53.775458
# 75%     67.892500   68.174997   67.447500   67.740000   66.565508
# max     95.139999   96.070000   93.720001   95.010002   94.565781
#
#              Volume
# count  7.800000e+02
# mean   2.978900e+07
# std    1.522319e+07
# min    7.425600e+06
# 25%    2.096685e+07
# 50%    2.623125e+07
# 75%    3.408020e+07
# max    1.691640e+08

# %%
ms.shape
# Out:
# (780, 6)

# %%
ms.loc['2015-01-02', 'Close']
# Out:
# 46.759998000000003

# %%
ms.index[-1]
# Out:
# Timestamp('2018-02-05 00:00:00')

# %%
ms.iloc[6, 4]
# Out:
# 43.531395000000003

# %%
fb.loc['2015-01-02':'2015-12-31', 'Close'].plot()

# %%
fb['Price1'] = fb['Close'].shift(-1)

# %%
fb['PriceDiff'] = fb['Price1'] - fb['Close']

# %%
fb['Return'] = fb['PriceDiff']/fb['Close']

# %%
fb['Direction'] = [1 if fb.loc[ei, 'PriceDiff'] > 0 else -1 for ei in fb.index]

# %%
fb['Average3'] = (fb['Close'] + fb['Close'].shift(1) + fb['Close'].shift(2)) / 3

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200
#
#                Price1  PriceDiff    Return  Direction   Average3
# Date
# 2014-12-31  20.129999   0.080000  0.003990          1        NaN
# 2015-01-02  19.790001  -0.339998 -0.016890         -1        NaN
# 2015-01-05  19.190001  -0.600000 -0.030318         -1  19.990000
# 2015-01-06  19.139999  -0.050002 -0.002606         -1  19.703334
# 2015-01-07  19.860001   0.720002  0.037618          1  19.373334

# %%
fb['MA40'] = fb['Close'].rolling(40).mean()

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200
#
#                Price1  PriceDiff    Return  Direction   Average3  MA40
# Date
# 2014-12-31  20.129999   0.080000  0.003990          1        NaN   NaN
# 2015-01-02  19.790001  -0.339998 -0.016890         -1        NaN   NaN
# 2015-01-05  19.190001  -0.600000 -0.030318         -1  19.990000   NaN
# 2015-01-06  19.139999  -0.050002 -0.002606         -1  19.703334   NaN
# 2015-01-07  19.860001   0.720002  0.037618          1  19.373334   NaN

# %%
fb['MA200'] = fb['Close'].rolling(200).mean()

# %%
fb['Close'].plot()
fb['MA40'].plot()
fb['MA200'].plot()

# %%
import matplotlib.pyplot as plt

fb['High'].plot()
plt.show()

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200
#
#                Price1  PriceDiff    Return  Direction   Average3  MA40  MA200
# Date
# 2014-12-31  20.129999   0.080000  0.003990          1        NaN   NaN    NaN
# 2015-01-02  19.790001  -0.339998 -0.016890         -1        NaN   NaN    NaN
# 2015-01-05  19.190001  -0.600000 -0.030318         -1  19.990000   NaN    NaN
# 2015-01-06  19.139999  -0.050002 -0.002606         -1  19.703334   NaN    NaN
# 2015-01-07  19.860001   0.720002  0.037618          1  19.373334   NaN    NaN

# %%
fb[['Open', 'Low']]
# Out:
#                   Open         Low
# Date
# 2014-12-31   20.400000   19.990000
# 2015-01-02   20.129999   19.809999
# 2015-01-05   20.129999   19.700001
# 2015-01-06   19.820000   19.170000
# 2015-01-07   19.330000   19.080000
# 2015-01-08   19.360001   19.350000
# 2015-01-09   19.930000   19.660000
# 2015-01-12   19.990000   19.510000
# 2015-01-13   19.840000   19.520000
# 2015-01-14   19.450001   19.400000
# 2015-01-15   19.879999   19.590000
# 2015-01-16   19.570000   19.510000
# 2015-01-20   20.100000   19.770000
# 2015-01-21   19.910000   19.770000
# 2015-01-22   20.340000   20.129999
# 2015-01-23   20.670000   20.500000
# 2015-01-26   20.620001   20.490000
# 2015-01-27   20.299999   19.590000
# 2015-01-28   19.870001   19.299999
# 2015-01-29   19.320000   19.230000
# 2015-01-30   19.639999   19.170000
# 2015-02-02   19.320000   18.940001
# 2015-02-03   19.760000   19.660000
# 2015-02-04   20.049999   19.990000
# 2015-02-05   20.180000   20.160000
# 2015-02-06   20.469999   20.309999
# 2015-02-09   20.280001   20.150000
# 2015-02-10   20.400000   20.309999
# 2015-02-11   21.000000   20.670000
# 2015-02-12   22.000000   21.870001
# ...                ...         ...
# 2017-12-21  196.940002  195.550003
# 2017-12-22  194.399994  191.250000
# 2017-12-26  193.029999  191.820007
# 2017-12-27  196.899994  196.309998
# 2017-12-28  198.130005  197.149994
# 2017-12-29  198.460007  193.500000
# 2018-01-02  195.779999  194.500000
# 2018-01-03  204.100006  203.750000
# 2018-01-04  215.759995  212.690002
# 2018-01-05  214.190002  211.080002
# 2018-01-08  220.399994  218.580002
# 2018-01-09  222.220001  218.639999
# 2018-01-10  218.199997  216.000000
# 2018-01-11  225.000000  223.210007
# 2018-01-12  223.600006  221.339996
# 2018-01-16  224.050003  216.690002
# 2018-01-17  220.699997  216.899994
# 2018-01-18  223.940002  222.679993
# 2018-01-19  228.089996  227.000000
# 2018-01-22  230.429993  228.100006
# 2018-01-23  235.850006  235.100006
# 2018-01-24  239.039993  233.550003
# 2018-01-25  238.000000  235.750000
# 2018-01-26  238.119995  237.600006
# 2018-01-29  242.740005  240.610001
# 2018-01-30  241.110001  238.410004
# 2018-01-31  245.770004  244.449997
# 2018-02-01  238.520004  238.059998
# 2018-02-02  237.000000  231.169998
# 2018-02-05  227.000000  205.000000
#
# [780 rows x 2 columns]

# %%
fb.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Price1',
#        'PriceDiff', 'Return', 'Direction', 'Average3', 'MA40', 'MA200'],
#       dtype='object')

# %%
die = pd.DataFrame([1, 2, 3, 4, 5, 6])

# %%
sum_of_dice = die.sample(2, replace = True).sum().loc[0]
print('Sum of the dice is', sum_of_dice)
# Out:
# Sum of the dice is 7

# %%
trial = 50
result = [die.sample(2, replace = True).sum().loc[0] for i in range(trial)]
result[:10]
# Out:
# [5, 8, 10, 9, 7, 11, 7, 6, 10, 8]
